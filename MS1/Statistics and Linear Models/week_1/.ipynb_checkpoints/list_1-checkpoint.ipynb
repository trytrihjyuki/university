# %%
import numpy as np
from scipy.stats import norm

from tqdm import tqdm
import itertools
import matplotlib.pyplot as plt

# %% [markdown]
# ### EX 1

# %%
NUM_SAMPLES = 50
NUM_EXP = 10000

# %%
def weights_4(i):
    return norm.pdf(norm.ppf((i-1)/NUM_SAMPLES)) - norm.pdf(norm.ppf(i/NUM_SAMPLES))
ws_4 = np.arange(1, NUM_SAMPLES + 1)
ws_4 = np.vectorize(weights_4)(ws_4)

def get_estimators(ns):
    t1 = np.sum(ns) / len(ns)
    
    t2 = np.median(ns)
    
    ws = np.random.randint(1, 100, NUM_SAMPLES)
    ws = ws / np.sum(ws)
    t3 = ns@ws
    
    ns_sorted = np.sort(ns)

    t4 = ns_sorted@ws_4
    
    return t1, t2, t3, t4

# %%
print(ws_4)
# Out:
# [-0.04841814 -0.03775564 -0.03294919 -0.02954326 -0.02683211 -0.02454215
#  -0.02253623 -0.02073503 -0.01908828 -0.0175619  -0.01613166 -0.01477961
#  -0.01349202 -0.01225813 -0.01106927 -0.00991834 -0.00879938 -0.00770735
#  -0.00663784 -0.00558701 -0.0045514  -0.00352786 -0.00251349 -0.00150556
#  -0.00050143  0.00050143  0.00150556  0.00251349  0.00352786  0.0045514
#   0.00558701  0.00663784  0.00770735  0.00879938  0.00991834  0.01106927
#   0.01225813  0.01349202  0.01477961  0.01613166  0.0175619   0.01908828
#   0.02073503  0.02253623  0.02454215  0.02683211  0.02954326  0.03294919
#   0.03775564  0.04841814]

# %%
summary = np.zeros((3,4,3))
estimators = ['t1', 't2', 't3', 't4']

# %%
for i, (mu, sigma) in enumerate([(1,1), (4,1), (1,2)]):
    results = np.zeros((4, NUM_EXP))
    for j in tqdm(range(NUM_EXP)):
        ns = np.random.normal(mu, sigma, NUM_SAMPLES)
        t1, t2, t3, t4 = get_estimators(ns)
        results[:, j] = np.array([t1, t2, t3, t4])
    
    print(f'mu: {mu} sigma: {sigma}')
    for j in range(4):
        var = results[j, :].var()
        mse = np.square(results[j, :] - np.full(NUM_EXP, mu)).mean()
        bias = (results[j, :] - np.full(NUM_EXP, mu)).mean()
        # print(f't_{j}:\nvar:{var}\nmse:{mse}\nbias{bias}\n##########\n')
        summary[i , j, :] = np.array([var, mse, bias])
# Out:
# 100%|█████████████████████████████████████████████| 10000/10000 [00:00<00:00, 14526.62it/s]
# mu: 1 sigma: 1
# 100%|█████████████████████████████████████████████| 10000/10000 [00:00<00:00, 15078.92it/s]
# mu: 4 sigma: 1
# 100%|█████████████████████████████████████████████| 10000/10000 [00:00<00:00, 15265.92it/s]
# mu: 1 sigma: 2

# %%
for i, (mu, sigma) in enumerate([(1,1), (4,1), (1,4)]):
    fig, axs = plt.subplots(3)
    fig.suptitle(f'mu:{mu} sigma:{sigma}')
    fig.set_figheight(10)
    fig.set_figwidth(13)
    axs[0].bar(estimators, summary[i,:,0], color='C1')
    axs[0].set_title('VAR')
    axs[1].bar(estimators, summary[i,:,1], color='C2')
    axs[1].set_title('MSE')
    axs[2].bar(estimators, summary[i,:,2])
    axs[2].set_title('BIAS')

# %% [markdown]
# ## EX2

# %% [markdown]
# It's useful to set seed before running experiments which are using semi-random generators. When we want to reproduce our results by achiving same random generated samples we can do this by defining same seed for this experiment

# %% [markdown]
# ## EX3

# %% [markdown]
# Sometimes we can't calculate solution of optimal likelihood estimator. Even if we can prove that solution exists it might be impossible or very hard to find the exact form of the solution. If this happens we can use numerical methods to find global maximum of likelihood function, this is the case when estimating the shifted parameter in the logistic distribution.

# %% [markdown]
# ## EX4

# %% [markdown]
# They have used Newton's method. At the beginning we have initial guess of desired function root, x_1. Then we get closer to the root, taking as a guess point which is in interception of tangent line (from derivative) and function's curve.. We recrusivly repeat the procees until we obtain satysfying approximation or do all the steps.

# %% [markdown]
# ## EX5

# %%
num_steps = [10, 100]
starting_point = [-500, -100, 0, 100, 500]
experiment_setups = list(itertools.product(num_steps, starting_point))
setups_desc = [f'N:{num} t_0:{t}' for num, t in experiment_setups]

NUM_SETUPS = len(experiment_setups)
ACC = 1e-4
NUM_EXP = 100
LR = 0.01

summary = np.zeros((3, 4))

# %%
def newton_logistic(theta, ns, num_steps=1000):

    def first_d(theta):
        return NUM_SAMPLES - 2*np.sum(np.exp(theta-ns)/(1+np.exp(theta-ns)))

    def second_d(theta):
        return 2*np.sum(np.exp(theta-ns)/((np.exp(theta-ns) + 1)**2))

    for i in range(num_steps):
        theta = theta - first_d(theta)/(second_d(theta)+1e-9)
        if abs(first_d(theta)) < ACC:
            return theta, i+1
    return theta, num_steps

# %%
def newton_cauchy( theta, ns, num_steps=200):

    def first_d(theta):
        return np.sum(2*(ns-theta)/(1+(ns-theta)**2))

    def second_d(theta):
        return 2*np.sum(((ns-theta)**2-1)/((1+(ns-theta)**2)**2))

    for i in range(num_steps):
        theta = theta - first_d(theta)/(second_d(theta)+1e-9)
        if abs(first_d(theta)) < ACC:
            return theta, i+1
    return theta, num_steps

# %%
for i, (mu, sigma) in enumerate([(1,1)]):#, (4,1), (1,2)]):
    results = np.zeros(NUM_EXP)
    steps = np.zeros(NUM_EXP)
    for k in tqdm(range(NUM_EXP)):
        ns = np.random.logistic(mu, sigma, NUM_SAMPLES)
        theta, kroki = newton_logistic(np.mean(ns), ns)
        results[k] = theta
        steps[k] = kroki

    # print(f'mu: {mu} sigma: {sigma}')
    var = results.var()
    mse = np.square(results - mu).mean()
    bias = (results - mu).mean()
    summary[i, :] = np.array([var, mse, bias, steps.mean()])
# Out:
#   0%|                                                   | 0/100 [00:00<?, ?it/s]/tmp/ipykernel_3802/2680503166.py:4: RuntimeWarning: overflow encountered in exp
#   return NUM_SAMPLES - 2*np.sum(np.exp(theta-ns)/(1+np.exp(theta-ns)))
# /tmp/ipykernel_3802/2680503166.py:4: RuntimeWarning: invalid value encountered in divide
#   return NUM_SAMPLES - 2*np.sum(np.exp(theta-ns)/(1+np.exp(theta-ns)))
# /tmp/ipykernel_3802/2680503166.py:7: RuntimeWarning: overflow encountered in exp
#   return 2*np.sum(np.exp(theta-ns)/((np.exp(theta-ns) + 1)**2))
# /tmp/ipykernel_3802/2680503166.py:7: RuntimeWarning: invalid value encountered in divide
#   return 2*np.sum(np.exp(theta-ns)/((np.exp(theta-ns) + 1)**2))
#   3%|█▎                                         | 3/100 [00:00<00:03, 27.50it/s]/tmp/ipykernel_3802/2680503166.py:7: RuntimeWarning: overflow encountered in square
#   return 2*np.sum(np.exp(theta-ns)/((np.exp(theta-ns) + 1)**2))
# ...

# %%
np.count_nonzero(np.isnan(results))
results[~np.isnan(results)]
# Out:
# array([-4.93500000e+13, -4.95000001e+13, -4.95500000e+13, -4.95000000e+13,
#        -4.94000000e+13, -4.96500000e+13, -4.96000000e+13, -4.97000000e+13,
#        -4.96021340e+13, -4.97000000e+13, -4.96500020e+13, -4.96000000e+13,
#        -4.92481131e+13, -4.96500000e+13, -4.95000000e+13, -4.96499996e+13,
#        -4.95500000e+13, -4.95500000e+13, -4.95500000e+13, -4.96999992e+13,
#        -4.95500000e+13, -4.96500000e+13, -4.96500001e+13, -4.95505311e+13,
#        -4.93499745e+13, -4.96500000e+13, -4.96000000e+13, -4.96000000e+13,
#        -4.96500000e+13, -4.96000000e+13, -4.95500000e+13, -4.96000498e+13,
#        -4.95500000e+13, -4.96510565e+13, -4.95500000e+13, -4.96000000e+13,
#        -4.96005120e+13, -4.96500000e+13, -4.95500000e+13, -4.95500000e+13,
#        -4.96000009e+13, -4.95500000e+13, -4.95500000e+13, -4.96500000e+13,
#        -4.96000000e+13, -4.95999925e+13, -4.94000000e+13, -4.95488664e+13])

# %%
# for i, (mu, sigma) in enumerate([(1,1), (4,1), (1,4)]):
fig, axs = plt.subplots(4)
# fig.suptitle(f'mu:{mu} sigma:{sigma}')
fig.set_figheight(15)
fig.set_figwidth(20)
axs[0].bar(['(1,1)', '(4,1)', '(1,2)'], summary[:,0],  color='C1')
axs[0].set_title('VAR')
axs[1].bar(['(1,1)', '(4,1)', '(1,2)'], summary[:,1],  color='C2')
axs[1].set_title('MSE')
axs[2].bar(['(1,1)', '(4,1)', '(1,2)'], summary[:,2],  color='C3')
axs[2].set_title('BIAS')
axs[3].bar(['(1,1)', '(4,1)', '(1,2)'], summary[:,3],  color='C4')
axs[3].set_title('STEPS')
summary[:,0]
# Out:
# array([nan, nan, nan])

# %%
steps
