# %%
import numpy as np
from scipy.stats import norm, binom, poisson

from tqdm import tqdm
import itertools
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as py

# %% [markdown]
# ### EX1

# %%
num_experiments = 10000
experiments = [[50, p] for p in [0.1, 0.3, 0.5, 0.7, 0.9]]
results = np.zeros((num_experiments, len(experiments)))

# %%
def get_mle(ns):
    p_hat = np.sum(ns) / (5*50)
    return 1 - ((1-p_hat)**5 + 5*p_hat*(1-p_hat)**4 + 10*p_hat**2*(1-p_hat)**3)

# %%
for i in range(num_experiments):
    for j, (n, p) in enumerate(experiments):
        ns = np.random.binomial(5, p, n)
        mle = get_mle(ns)
        results[i][j] = mle

# %%
for j, (n, p) in enumerate(experiments):
    true_value = 1 - ((1-p)**5 + 5*p*(1-p)**4 + 10*p**2*(1-p)**3)
    var = results[:,j].var()
    mse = ((results[:,j] - true_value)**2).mean()
    bias = (results[:,j] - true_value).mean()
    print(f'p:{p}\nvar: {var}\nmse: {mse}\nbias: {bias}\n\n')
# Out:
# p:0.1
# var: 2.438969152184836e-05
# mse: 2.5048177124424063e-05
# bias: 0.0008114712580096146
#
#
# p:0.3
# var: 0.0014731437790918233
# mse: 0.0014775121321002542
# bias: 0.0020900605274563086
#
#
# p:0.5
# var: 0.003490088455177184
# mse: 0.0034900951418213246
# bias: 8.17719031258875e-05
#
#
# p:0.7
# var: 0.0014881800689048991
# mse: 0.0014949164644727534
# bias: -0.0025954567166213047
#
#
# p:0.9
# var: 2.4641375160164514e-05
# mse: 2.5247386617886154e-05
# bias: -0.0007784673774292902

# %% [markdown]
# ### EX2

# %%
num_experiments = 10000
experiments = [[50, lam] for lam in [0.5, 1, 2, 5]]
results = np.zeros((num_experiments, len(experiments), 11))

# %%
def get_mle(ns, k):
    lam = ns.mean()
    return np.power(lam, k)*np.exp(-lam) / np.math.factorial(k)

# %%
for i in range(num_experiments):
    for j, (n, lam) in enumerate(experiments):
        for k in range(11):
            ns = np.random.poisson(lam=lam, size=n)
            mle = get_mle(ns, k)
            results[i][j][k] = mle

# %%
for j, (n, lam) in enumerate(experiments):
    for k in range(11):
        true_value = np.power(lam, k)*np.exp(-lam) / np.math.factorial(k)
        var = results[:,j,k].var()
        mse = ((results[:,j,k] - true_value)**2).mean()
        bias = (results[:,j,k] - true_value).mean()
        mean = results[:,j,k].mean()
        print(f'p:{lam} x:{k}\nvar: {var}\nmse: {mse}\nbias: {bias}\nmean: {mean}\ntrue_value: {true_value}\n\n')
# Out:
# p:0.5 x:0
# var: 0.0036855240998371593
# mse: 0.0036935273132327586
# bias: 0.0028289951211692157
# mean: 0.6093596548338028
# true_value: 0.6065306597126334
#
#
# p:0.5 x:1
# var: 0.0009530956308384656
# mse: 0.0009701528021269793
# bias: -0.004130032843515122
# mean: 0.29913529701280156
# true_value: 0.3032653298563167
#
#
# p:0.5 x:2
# var: 0.000510580610520765
# mse: 0.0005109371447404212
# bias: 0.0005971048648739797
# mean: 0.07641343732895316
# true_value: 0.07581633246407918
#
#
# p:0.5 x:3
# var: 4.231388683604918e-05
# mse: 4.291796979357494e-05
# bias: 0.0007772277385205405
# mean: 0.013413283149200407
# true_value: 0.012636055410679864
#
#
# p:0.5 x:4
# var: 1.5902496757452263e-06
# mse: 1.6625550643793452e-06
# bias: 0.00026889661328123593
# mean: 0.0018484035396162189
# true_value: 0.001579506926334983
#
#
# p:0.5 x:5
# var: 3.618211089161267e-08
# mse: 3.866872501810161e-08
# bias: 4.986596160196804e-05
# mean: 0.0002078166542354663
# true_value: 0.0001579506926334983
#
#
# p:0.5 x:6
# var: 5.159888944059641e-10
# mse: 5.618973299569132e-10
# bias: 6.775576399904962e-06
# mean: 1.9938134119363152e-05
# true_value: 1.316255771945819e-05
#
#
# p:0.5 x:7
# var: 6.344846554653328e-12
# mse: 7.003587284699137e-12
# bias: 8.116284433444955e-07
# mean: 1.7518111375915091e-06
# true_value: 9.401826942470136e-07
#
#
# p:0.5 x:8
# var: 5.272622498400973e-14
# mse: 5.835669429038957e-14
# bias: 7.50364531836349e-08
# mean: 1.3379787157407324e-07
# true_value: 5.876141839043835e-08
#
#
# p:0.5 x:9
# var: 4.4136250845286896e-16
# mse: 4.819509802486349e-16
# bias: 6.370908239471512e-09
# mean: 9.635431483384752e-09
# true_value: 3.2645232439132415e-09
#
#
# p:0.5 x:10
# var: 2.5885207518073755e-18
# mse: 2.7940845103665647e-18
# bias: 4.53391396653255e-10
# mean: 6.166175588489171e-10
# true_value: 1.6322616219566209e-10
#
#
# p:1 x:0
# var: 0.0027347339815069413
# mse: 0.002750638487828454
# bias: 0.00398804542620986
# mean: 0.3718674865976523
# true_value: 0.36787944117144233
#
#
# p:1 x:1
# var: 2.847691024112723e-05
# mse: 4.221928404252233e-05
# bias: -0.0037070707845137107
# mean: 0.3641723703869286
# true_value: 0.36787944117144233
#
#
# p:1 x:2
# var: 0.0006585486753552147
# mse: 0.0006615862505343174
# bias: -0.0017428640736163882
# mean: 0.18219685651210477
# true_value: 0.18393972058572117
#
#
# p:1 x:3
# var: 0.0002848308757011794
# mse: 0.00028527143475188816
# bias: 0.0006637462246286136
# mean: 0.06197698641986901
# true_value: 0.06131324019524039
#
#
# p:1 x:4
# var: 4.367152482394234e-05
# mse: 4.416184488163819e-05
# bias: 0.0007002285753208476
# mean: 0.016028538624130947
# true_value: 0.015328310048810098
#
#
# p:1 x:5
# var: 3.589854325310591e-06
# mse: 3.7097876987170304e-06
# bias: 0.00034631398095722317
# mean: 0.0034119759907192426
# true_value: 0.0030656620097620196
#
#
# p:1 x:6
# var: 1.8528614867746512e-07
# mse: 1.9458687136415765e-07
# bias: 9.644025449309289e-05
# mean: 0.0006073839227867629
# true_value: 0.0005109436682936699
#
#
# p:1 x:7
# var: 7.151743817875453e-09
# mse: 7.669598270981207e-09
# bias: 2.275641564714786e-05
# mean: 9.574836826052928e-05
# true_value: 7.299195261338141e-05
#
#
# p:1 x:8
# var: 2.0903346295365919e-10
# mse: 2.2794068703539936e-10
# bias: 4.348243792813388e-06
# mean: 1.3472237869486065e-05
# true_value: 9.123994076672677e-06
#
#
# p:1 x:9
# var: 4.512293471609693e-12
# mse: 4.937683983792134e-12
# bias: 6.522196809223415e-07
# mean: 1.6659968005526389e-06
# true_value: 1.0137771196302974e-06
#
#
# p:1 x:10
# var: 9.172171370797907e-14
# mse: 1.0044489994039627e-13
# bias: 9.339799908144276e-08
# mean: 1.947757110444725e-07
# true_value: 1.0137771196302975e-07
#
#
# p:2 x:0
# var: 0.0007808100652275022
# mse: 0.0007901060578229841
# bias: 0.0030489330257455556
# mean: 0.13838421626235822
# true_value: 0.1353352832366127
#
#
# p:2 x:1
# var: 0.000700177413374623
# mse: 0.0007001788532999024
# bias: 3.794634737756826e-05
# mean: 0.270708512820603
# true_value: 0.2706705664732254
#
#
# p:2 x:2
# var: 1.4673472747206578e-05
# mse: 2.211103837828423e-05
# bias: -0.0027271900614144313
# mean: 0.267943376411811
# true_value: 0.2706705664732254
#
#
# p:2 x:3
# var: 0.0003200963367969158
# mse: 0.0003228712096500673
# bias: -0.001665794961317741
# mean: 0.17878124935416587
# true_value: 0.1804470443154836
#
#
# p:2 x:4
# var: 0.0003119512706857343
# mse: 0.00031195575730219474
# bias: -6.698221002976622e-05
# mean: 0.09015653994771204
# true_value: 0.0902235221577418
#
#
# p:2 x:5
# var: 0.00011760953875915024
# mse: 0.00011808172094983535
# bias: 0.000687155143097343
# mean: 0.036776564006194064
# true_value: 0.03608940886309672
#
#
# p:2 x:6
# var: 2.4797267220634e-05
# mse: 2.516931583206638e-05
# bias: 0.0006099578767688606
# mean: 0.012639760831134434
# true_value: 0.012029802954365574
#
#
# p:2 x:7
# var: 3.5033397047696557e-06
# mse: 3.604662587313289e-06
# bias: 0.0003183125548005184
# mean: 0.003755399113190682
# true_value: 0.0034370865583901638
#
#
# p:2 x:8
# var: 3.5062626053451553e-07
# mse: 3.6562603288924545e-07
# bias: 0.00012247355777770941
# mean: 0.0009817451973752503
# true_value: 0.0008592716395975409
#
#
# p:2 x:9
# var: 2.5597703257542022e-08
# mse: 2.698626716725024e-08
# bias: 3.726343931668436e-05
# mean: 0.0002282126925605823
# true_value: 0.00019094925324389798
#
#
# p:2 x:10
# var: 1.746652786844898e-09
# mse: 1.875088749859744e-09
# bias: 1.1332959146438596e-05
# mean: 4.952280979521819e-05
# true_value: 3.8189850648779595e-05
#
#
# p:5 x:0
# var: 5.211970890696076e-06
# mse: 5.351883548167128e-06
# bias: 0.00037404900410381055
# mean: 0.007111996003189278
# true_value: 0.006737946999085467
#
#
# p:5 x:1
# var: 7.74148336495706e-05
# mse: 7.824774154008288e-05
# bias: 0.0009126378747960558
# mean: 0.03460237287022339
# true_value: 0.03368973499542734
#
#
# p:5 x:2
# var: 0.0002574315726843996
# mse: 0.0002581808849479937
# bias: 0.0008656282479182703
# mean: 0.0850899657364866
# true_value: 0.08422433748856833
#
#
# p:5 x:3
# var: 0.0003019898727698304
# mse: 0.0003019917992666834
# bias: -4.389187684639476e-05
# mean: 0.14033000393743417
# true_value: 0.14037389581428056
#
#
# p:5 x:4
# var: 0.00011772085050442072
# mse: 0.00011888770359633876
# bias: -0.0010802097444098607
# mean: 0.17438716002344085
# true_value: 0.1754673697678507
#
#
# p:5 x:5
# var: 5.678309630436386e-06
# mse: 8.617938174498062e-06
# bias: -0.0017145344977753216
# mean: 0.1737528352700754
# true_value: 0.1754673697678507
#
#
# p:5 x:6
# var: 8.61542964220066e-05
# mse: 8.799335370471153e-05
# bias: -0.0013561184618995968
# mean: 0.144866689677976
# true_value: 0.1462228081398756
#
#
# p:5 x:7
# var: 0.00016731657955744162
# mse: 0.00016750810875620114
# bias: -0.00043764049031083793
# mean: 0.10400722246674315
# true_value: 0.104444862957054
#
#
# p:5 x:8
# var: 0.00014605911466593073
# mse: 0.00014613935417153714
# bias: 0.0002832657861556947
# mean: 0.06556130513431445
# true_value: 0.06527803934815875
#
#
# p:5 x:9
# var: 8.469417309929637e-05
# mse: 8.497198591042207e-05
# bias: 0.0005270795111989246
# mean: 0.03679265692684268
# true_value: 0.03626557741564375
#
#
# p:5 x:10
# var: 3.320459005066231e-05
# mse: 3.347137542783849e-05
# bias: 0.0005165127076618472
# mean: 0.01864930141548372
# true_value: 0.01813278870782187

# %% [markdown]
# ### EX3

# %%
num_experiments = 10000
experiments = [[50, t] for t in [0.5, 1, 2, 5]]
results = np.zeros((num_experiments, len(experiments), 3))

# %%
def get_mle(ns):
    n = len(ns)
    t = -n / np.sum(np.log(ns))
    return  t, (2*t**2 + 2*t + 1) / n

# %%
for i in range(num_experiments):
    for j, (n, beta) in enumerate(experiments):
        ns = np.random.beta(beta, 1, size=n)
        mle_t, mle_f = get_mle(ns)
        results[i][j][0] = mle_t
        results[i][j][1] = mle_f
        results[i][j][2] = np.sqrt(mle_f*n)*(mle_t-beta)

# %%
fig, axs = plt.subplots(4, figsize=(15, 10))
for j, (n, beta) in enumerate(experiments):
    axs[j].set_title(f'{beta}')
    axs[j].hist(results[:,j,2], bins=int(np.sqrt(len(results[:,j,2]))))

# %%
for j, (n, beta) in enumerate(experiments):
    sm.qqplot(results[:,j,2], line ='45')
    py.show()
